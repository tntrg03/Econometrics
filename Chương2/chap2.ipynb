# %%
library(hexView)

# %% [markdown]
# # Bài 2.1

# %%
b21 <- readEViews("ch2bt1.WF1")
# Out:
# Warning message in readEViews("ch2bt1.WF1"):
# "Skipping boilerplate variable
# "
# Warning message in readEViews("ch2bt1.WF1"):
# "Skipping boilerplate variable
# "

# %% [markdown]
# ## 2.1.1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# cor(X_1,X_2)=\frac{Cov(X_1,X_2)}{\sigma_1\sigma_2}
# $$

# %%
cor(b21$X1,b21$X2)
# Out:
# [1] 0

# %% [markdown]
# ## 2.1.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \begin{cases}
# \sum_{i=1}(Y_i-\beta_0-\beta_1X_{1i})=0\\
# \sum_{i=1}X_{1i}(Y_i-\beta_0-\beta_1X_{1i})=0
# \end{cases}
# $$

# %%
summary(lm(data=b21,Y~X1))
# Out:
# Call:
# lm(formula = Y ~ X1, data = b21)
#
# Residuals:
#       1       2       3       4       5       6       7
#  2.5470 -2.9923 -0.1619 -0.5634 -1.9027 -1.1841  4.2573
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    7.805      3.285   2.376   0.0635 .
# X1             1.090      0.573   1.902   0.1156
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.79 on 5 degrees of freedom
# Multiple R-squared:  0.4197,	Adjusted R-squared:  0.3036
# F-statistic: 3.616 on 1 and 5 DF,  p-value: 0.1156

# %% [markdown]
# ## 2.1.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \begin{cases}
# \sum_{i=1}(Y_i-\beta_0-\beta_1X_{1i})=0\\
# \sum_{i=1}X_{1i}(Y_i-\beta_0-\beta_1X_{1i})=0
# \end{cases}
# $$

# %%
summary(lm(data=b21,Y~X2))
# Out:
# Call:
# lm(formula = Y ~ X2, data = b21)
#
# Residuals:
#       1       2       3       4       5       6       7
#  0.5943  0.6749  4.2821 -3.2929 -1.5146 -2.6523  1.9086
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  13.3290     1.1322  11.773 7.78e-05 ***
# X2            0.3128     0.1867   1.676    0.155
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.931 on 5 degrees of freedom
# Multiple R-squared:  0.3596,	Adjusted R-squared:  0.2316
# F-statistic: 2.808 on 1 and 5 DF,  p-value: 0.1546

# %% [markdown]
# ## 2.1.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$
# \begin{cases}
# \sum_{i=1}(Y_i-\beta_0-\beta_1X_{1i}-\beta_2X_{2i})=0\\
# \sum_{i=1}X_{1i}(Y_i-\beta_0-\beta_1X_{1i}-\beta_2X_{2i})=0\\
# \sum_{i=1}X_{2i}(Y_i-\beta_0-\beta_1X_{1i}-\beta_2X_{2i})=0
# \end{cases}
# $$

# %%
summary(lm(data=b21,Y~X1+X2))
# Out:
# Call:
# lm(formula = Y ~ X1 + X2, data = b21)
#
# Residuals:
#      1      2      3      4      5      6      7
#  1.061 -1.037  1.480 -1.736 -2.137  1.084  1.286
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   7.4138     2.2696   3.267   0.0309 *
# X1            1.0896     0.3950   2.758   0.0509 .
# X2            0.3128     0.1225   2.553   0.0631 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.924 on 4 degrees of freedom
# Multiple R-squared:  0.7793,	Adjusted R-squared:  0.669
# F-statistic: 7.064 on 2 and 4 DF,  p-value: 0.04869

# %% [markdown]
# # Bài 2.2

# %% [markdown]
# ## 2.2.1

# %% [markdown]
# $$
# cor(Y,X_3)=\frac{Cov(Y,X_3)}{\sigma_Y\sigma_3}
# $$

# %%
cor(b21$Y,b21$X3)
# Out:
# [1] -1.596314e-07

# %% [markdown]
# ## 2.2.2

# %% [markdown]
# $$
# \begin{cases}
# \sum_{i=1}(Y_i-\beta_0-\beta_3X_{3i})=0\\
# \sum_{i=1}X_{3i}(Y_i-\beta_0-\beta_3X_{3i})=0
# \end{cases}
# $$

# %%
summary(lm(data=b21,Y~X3))
# Out:
# Call:
# lm(formula = Y ~ X3, data = b21)
#
# Residuals:
#     1     2     3     4     5     6     7
#  2.08 -1.28  2.64 -2.12 -1.28 -4.92  4.88
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.372e+01  1.487e+00   9.224 0.000251 ***
# X3          -4.527e-07  1.268e+00   0.000 1.000000
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.663 on 5 degrees of freedom
# Multiple R-squared:  2.548e-14,	Adjusted R-squared:   -0.2
# F-statistic: 1.274e-13 on 1 and 5 DF,  p-value: 1

# %% [markdown]
# ## 2.2.3

# %% [markdown]
# $$
# \begin{cases}
# \sum_{i=1}(Y_i-\beta_0-\beta_1X_{1i})=0\\
# \sum_{i=1}X_{1i}(Y_i-\beta_0-\beta_1X_{1i})=0
# \end{cases}
# $$

# %%
summary(lm(data=b21,Y~X1))
# Out:
# Call:
# lm(formula = Y ~ X1, data = b21)
#
# Residuals:
#       1       2       3       4       5       6       7
#  2.5470 -2.9923 -0.1619 -0.5634 -1.9027 -1.1841  4.2573
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    7.805      3.285   2.376   0.0635 .
# X1             1.090      0.573   1.902   0.1156
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 2.79 on 5 degrees of freedom
# Multiple R-squared:  0.4197,	Adjusted R-squared:  0.3036
# F-statistic: 3.616 on 1 and 5 DF,  p-value: 0.1156

# %% [markdown]
# ## 2.2.4

# %% [markdown]
# $$
# \begin{cases}
# \sum_{i=1}(Y_i-\beta_0-\beta_1X_{1i}-\beta_3X_{3i})=0\\
# \sum_{i=1}X_{1i}(Y_i-\beta_0-\beta_1X_{1i}-\beta_3X_{3i})=0\\
# \sum_{i=1}X_{3i}(Y_i-\beta_0-\beta_1X_{1i}-\beta_3X_{3i})=0
# \end{cases}
# $$

# %%
summary(lm(data=b21,Y~X1+X3))
# Out:
# Call:
# lm(formula = Y ~ X1 + X3, data = b21)
#
# Residuals:
#         1         2         3         4         5         6         7
#  1.130671 -2.952425  0.006033 -0.285401 -1.767458 -0.875057  4.743638
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   7.0445     3.8434   1.833    0.141
# X1            1.1850     0.6466   1.833    0.141
# X3            0.5667     1.0902   0.520    0.631
#
# Residual standard error: 3.019 on 4 degrees of freedom
# Multiple R-squared:  0.4564,	Adjusted R-squared:  0.1846
# F-statistic: 1.679 on 2 and 4 DF,  p-value: 0.2955

# %% [markdown]
# # Bài 2.3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b23 <- readEViews("ch2bt3.wf1")
# Out:
# Warning message in readEViews("ch2bt3.wf1"):
# "Skipping boilerplate variable
# "
# Warning message in readEViews("ch2bt3.wf1"):
# "Skipping boilerplate variable
# "

# %%
summary(lm(data = b23, WAGE~GRADE))
# Out:
# Call:
# lm(formula = WAGE ~ GRADE, data = b23)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -10.673  -4.717  -2.046   2.096  52.954
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.1646     3.8160   1.091  0.27780
# GRADE         0.9068     0.3098   2.927  0.00425 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 8.619 on 98 degrees of freedom
# Multiple R-squared:  0.0804,	Adjusted R-squared:  0.07102
# F-statistic: 8.568 on 1 and 98 DF,  p-value: 0.004252

# %% [markdown]
# 1) Lương trung bình tăng 0.906
#
# 2) $\widehat{wage}=15.036<\overline{wage}$

# %% [markdown]
# # Bài 2.4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1)
#
# - $\hat \beta_2=0.566>0$ là số năm đi học tăng lên thì có xu hướng làm tăng mức lương nhận được
# - $\hat \beta_3=0.016>0$ là mức lương nhận được tăng nhiều hơn sau mỗi năm đi học
#
# 2)
# - Không phản ánh, số năm đi học nhiều hơn thì lương trung bình tăng nhiều hơn so với trước
#
# 3)
# - $\overline R^2$ giảm nên cho 2.3

# %% [markdown]
# # Bài 2.5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1) mức lương trung bình tăng 1.33
#
# 2) $\widehat{wage}=-6.85+1.33\times 12+0.306\times 19.48=15.07088>2.3)$
#
# 3) Tác động riêng phần của năm học lên mức lương là tác động của số năm học lên mức lương trong điều kiện các yếu tố khác đều giữ nguyên
#
# 4)
#
# - Đổi 1 năm kinh nghiệm cho 1 năm đi học: 1.33-0.306=1.024
# - Đổi 1 năm đi học cho 1 năm kinh nghiệm: 0.306-1.33=-1.024

# %% [markdown]
# # Bài 2.6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1)
#
# - $\hat\beta_1:$ Mức lương trung bình khi không đi học và không kinh nghiệm
#
# - $\hat\beta_2:$ Năm đi học tăng 1 năm thì mức lương tăng 8%
#
# - $\hat\beta_3:$ Năm kinh nghiệm tăng 1 năm thì mức lương tăng 2%
#
# 2)
#
# 3) Không. $R^2$ tăng khi thêm biến vào
#
# 4) Dùng $\overline R^2$

# %% [markdown]
# # Bài 2.7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1)
#
# - Khi người lao động có 1 năm kinh nghiệm vào 1 năm đi học thì tiền lương trung bình là $e^{-0.19}$
# - Khi năm đi học 1% thì tiền lương tăng 0.8%
# - Khi năm kinh nghiệm 1% thì tiền lương tăng 0.3%
#
# 2)
#
# - $\widehat{wage}=14.96323$
#
# 3)
# - Nhỏ hơn 2.5

# %% [markdown]
# # Bài 2.8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1)
# - Quy mô càng lớn thì lợi tức càng lớn ⇒ phù hợp
# - Beta càng lớn ⇒ rủi ro cao ⇒ lợi suất lớn ⇒ phù hợp

# %% [markdown]
# 2)
# - Size tăng 1 thì lợi suất tăng xấp xỉ 0.5
# - Beta tăng 1 thì lợi suất tăng xấp xỉ 1.2

# %% [markdown]
# 3)
# - Không, cần biết thêm về đơn vị đo

# %% [markdown]
# # Bài 2.9

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1) \>0
# 2) Có tương quan ⇒ ko đưa vào

# %% [markdown]
# # Bài 2.10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sai, tương quan cao vs smoke

# %% [markdown]
# # Bài 2.11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
summary(lm(b21$Y~1))$r.squared
# Out:
# [1] 0
